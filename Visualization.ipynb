# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
r = np.linspace(-5,5)
E0 = 0.2 
C = 0.045
V = E0*(C*r**4-r**2)


plt.plot(r,V)

# %%
xmin = np.sqrt(1/2/C)
xmin
# Out:
# 3.3333333333333335
